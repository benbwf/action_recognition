# %% [markdown]
# # Extract clips of actions from full video
# ### Using the annotations provided
#
# After clip is extracted, the next steps are getting the frames and splitting

# %% [markdown]
# ## Setup

# %%
import json
import glob
import cv2
import os
from numpy import random
from pathlib import Path
from matplotlib import pyplot as plt
from env_vars import VIDEOS_DIR, PREPROCESSED_DATA_ROOT, CLIPS_DIR
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from collections import defaultdict
print(f'{VIDEOS_DIR}\n{PREPROCESSED_DATA_ROOT}\n{CLIPS_DIR}')
# Out:
# C:\Users\User1\Desktop\projects\ITE_APAMS\ite_dataset\videos
# C:\Users\User1\Desktop\projects\ITE_APAMS
# C:\Users\User1\Desktop\projects\ITE_APAMS\ite_dataset\clips

# %%
#make clips dir
Path(CLIPS_DIR).mkdir(exist_ok=True)

# %% [markdown]
# ### Get paths of all video files

# %%
#get paths of all video files
video_files_paths = glob.glob(os.path.join(VIDEOS_DIR,'*', '*', '*.MP4'))[:20]
vid_path_dict = {}
for path in video_files_paths:
    vid_filename = os.path.basename(path)
    vid_path_dict[vid_filename] = path

# %%
vid_path_dict
# Out:
# {'VID00002.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210302\\A\\VID00002.MP4',
#  'A_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\A\\A_1.MP4',
#  'A_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\A\\A_2.MP4',
#  'A_3.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\A\\A_3.MP4',
#  'B1_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\B\\B1_1.MP4',
#  'B1_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\B\\B1_2.MP4',
#  'B2_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\B\\B2_1.MP4',
#  'C1_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\CD\\C1_1.MP4',
#  'C1_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\CD\\C1_2.MP4',
#  'C1_3.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\CD\\C1_3.MP4',
#  'E1_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\E\\E1_1.MP4',
#  'E1_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\E\\E1_2.MP4',
#  'E1_3.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\E\\E1_3.MP4',
#  'F1_1_1.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\F\\F1_1_1.MP4',
#  'F1_1_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\F\\F1_1_2.MP4',
#  'F1_2_1 (till 1.03).MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\F\\F1_2_1 (till 1.03).MP4',
#  'F1_2_2.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\F\\F1_2_2.MP4',
#  'F1_3.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210304\\F\\F1_3.MP4',
#  'A_4.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210305\\A\\A_4.MP4',
#  'A_5.MP4': 'C:\\Users\\User1\\Desktop\\projects\\ITE_APAMS\\ite_dataset\\videos\\210305\\A\\A_5.MP4'}

# %% [markdown]
# ### Get all json file paths and json data

# %%
#get all json file paths
json_files = glob.glob(os.path.join(VIDEOS_DIR,'*', '*', '*.json'))[:20]

#remove old annotations

#get list of json filenames
filenames = [os.path.basename(json_file) for json_file in json_files]

#filter out json files that have new version
# for json_file in json_files:
#     filename = os.path.basename(json_file)
#     dirname = os.path.dirname(json_file)
#     filename_base = filename[:-5]
#     if filename_base+'_new.json' in filenames:
# #         print('removing: ',json_file)
#         json_files.remove(json_file)
        
#read json into list
data_list = []
for file_name in json_files:
    with open(file_name) as file:
        data = json.load(file)
        data_list.append(data)

# %%
for path in json_files:
    parts = path.split('\\')
    if len(parts)!=11:
        print(path)

# %% [markdown]
# ### Get timespans for each action on each video:
# - (action_name, video_filename, annotation_id, z)
# - z: timespan in secs?
#
# #### Key Details from Exploring the JSON
# - data['metadata'] = annotations
# - data['metadata'].keys() = annotation ids
# - data['metadata']['annotation_id']['av'].keys() = attribute ids
# - data['metadata']['annotation_id']['av']['attribute_id'] = label

# %%
#ann_dict where each key is a video filename and the values are the annotations that pertain to that video
ann_dict = defaultdict(list)

#iterate through each json file
for data in data_list:
    """
    metadata is a dictionary of annotations like:
    annotation_id: {annotation}
    
    """
    for annotation_id, annotation_dict in data['metadata'].items():
        
        z = annotation_dict['z'] # time
        
        # attribute values: each annotation has multiple attributes. Each attribute can either 
        #have an object and action, or just an action
        av = annotation_dict['av'] 
        

        
        attr_names = []
        action_attr_id = 0
        for attribute_id in av.keys():
            attr_name = data['attribute'][attribute_id]['aname']
            attr_names.append(attr_name)
            if attr_name == 'action':
                action_attr_id = attribute_id # store the attribute_id for action
                
        #skip if it's an annotation for an object
        if 'object' in attr_names or len(z)!=2:
            continue
            
        video_id = annotation_dict['vid'] #id of video file for this annotation
        video_filename = data['file'][video_id]['fname']
        action_name = av[action_attr_id]
        
        print(action_name, video_filename, annotation_id, z)

        ann_dict[video_filename].append({'action_name':action_name, 'annotation_id':annotation_id, 'z':z})
# Out:
# switch_off_power_source VID00002.MP4 1_3RYVLAUg [176.175, 178.615]
# place_anti_static_mat VID00002.MP4 1_ZxoZlxCY [190.955, 193.175]
# disconnect_display_cable VID00002.MP4 1_2fACxd5g [220.892, 222.332]
# wear_wrist_wrap VID00002.MP4 1_HIS8BxKg [251.104, 261.164]
# wear_wrist_wrap VID00002.MP4 1_Dt4WCi33 [269.374, 271.303]
# remove_hdd VID00002.MP4 1_lIKYJHrJ [372.676, 376.527]
# disconnect_hdd_power_cable VID00002.MP4 1_9ELOuiqh [315.147, 319.43]
# disconnect_odd_power_cable VID00002.MP4 1_DSEbHcOd [418.23, 424.343]
# remove_odd VID00002.MP4 1_8WN61nUT [444.834, 449.174]
# remove_vga VID00002.MP4 1_XpFLUMWs [483.702, 486.898]
# remove_ram VID00002.MP4 1_rVFlLbxw [494.668, 496.337]
# remove_ram VID00002.MP4 1_0vnDxNjw [499.736, 501.656]
# insert_ram VID00002.MP4 1_BL2tuwpo [879.009, 888.897]
# insert_odd VID00002.MP4 1_GCmCsfKD [905.381, 913.575]
# connect_odd_power_cable VID00002.MP4 1_zk3GqD1M [955.527, 968.027]
# connect_odd_data_cable VID00002.MP4 1_0UyEF6I2 [984.147, 998.182]
# insert_hdd VID00002.MP4 1_BUbt32UX [1004.29, 1014.361]
# connect_hdd_data_cable VID00002.MP4 1_2SqLHFLp [1078.889, 1090.095]
# connect_hdd_power_cable VID00002.MP4 1_0elJu2vE [1090.138, 1092.835]
# insert_vga VID00002.MP4 1_EU1DdcpO [1098.527, 1117.327]
# connect_display_cable VID00002.MP4 1_XsJXfByo [1232.412, 1239.92]
# disconnect_atx_cable VID00002.MP4 1_OQEq34kv [565.863, 573.135]
# enter_bios_mode VID00002.MP4 1_OufvOAFj [1530.777, 1533.347]
# turn_on_pc VID00002.MP4 1_C2rXU9in [24.626, 25.626]
# login_screen VID00002.MP4 1_5aTA0Zip [119.921, 121.963]
# switch_off_power VID00002.MP4 1_oAppfQhZ [169.926, 172.092]
# place_anti_static_mat VID00002.MP4 1_bloQvRKV [198.028, 199.448]
# connect_alligator_clip VID00002.MP4 1_iBNtVALX [248.264, 250.514]
# remove_pc_casing VID00002.MP4 1_PMIpLrrV [282.733, 286.004]
# disconnect_hdd_data_cable VID00002.MP4 1_Mk3qFd6A [313.027, 314.027]
# disconnect_odd_data_cable VID00002.MP4 1_6UXWSPWd [508.027, 513.836]
# disconnect_hdd_data_cable VID00002.MP4 1_odybUNT4 [521.963, 523.671]
# insert_ram VID00002.MP4 1_GijpMEaP [851.912, 859.176]
# connect_atx_cable VID00002.MP4 1_hiTv8pQJ [889.21, 891.605]
# put_back_pc_casing VID00002.MP4 1_RXV6Phra [1157.819, 1165.04]
# place_anti_static_mat VID00002.MP4 1_48zTPKVy [1323.277, 1324.586]
# turn_on_pc VID00002.MP4 1_absrRXNy [1366.575, 1368.182]
# switch_off_power VID00002.MP4 1_Bvg1DQjt [1513.254, 1513.968]
# turn_on_pc VID00002.MP4 1_lQ8zt5mp [1518.509, 1521.009]
# verify_boot_sequence VID00002.MP4 1_2neDu26s [1550.889, 1553.067]
# login_screen A_3.MP4 1_eZiWNyeT [38.028, 40.305]
# login_screen A_2.MP4 2_DZse0QF4 [90.838, 92.296]
# login_screen A_1.MP4 3_uwXbb71Z [38.731, 41.055]
# turn_on_pc A_3.MP4 1_Fx7P9aBk [4.731, 7.231]
# turn_on_pc A_2.MP4 2_SeeKUfh9 [1.176, 3.596]
# turn_on_pc A_1.MP4 3_O1lYRIxV [4.19, 5.898]
# place_anti_static_mat B1_1.MP4 1_Pk1BOJoX [146.078, 152.71]
# unplug_power_cable B1_1.MP4 1_zwAjs73E [161.883, 162.923]
# wear_wrist_wrap B1_1.MP4 1_rZmNBMXn [192.055, 195.106]
# connect_alligator_clip B1_1.MP4 1_X34NsCC5 [212.838, 214.505]
# switch_off_power_source B1_1.MP4 1_jTsVIXbS [117.984, 122.848]
# remove_pc_casing B1_1.MP4 1_t0zDUnMX [181.189, 183.191]
# switch_off_power B1_1.MP4 1_HXffezZj [114.086, 115.731]
# disconnect_display_cable B1_1.MP4 1_XflDzFaE [165.318, 167.018]
# switch_off_power B1_2.MP4 2_y96r3RQV [51.031, 52.031]
# switch_off_power_source B1_2.MP4 2_iWg8AtRd [57.451, 60.018]
# place_anti_static_mat B1_2.MP4 2_ayOC0aHq [79.086, 85.764]
# unplug_power_cable B1_2.MP4 2_Er9yrFKA [92.606, 94.669]
# wear_wrist_wrap B1_2.MP4 2_VL3MJMBu [115.627, 119.336]
# connect_alligator_clip B1_2.MP4 2_iuAqhqiz [124.086, 126.627]
# remove_pc_casing B1_2.MP4 2_TglS6h0r [133.139, 135.424]
# disconnect_display_cable B1_2.MP4 2_q8mvUfVx [99.083, 100.435]
# switch_off_power B2_1.MP4 3_JBLza7nD [61.014, 62.014]
# switch_off_power_source B2_1.MP4 3_teMvJAFf [65.236, 71.023]
# place_anti_static_mat B2_1.MP4 3_9beAA70D [92.419, 98.501]
# unplug_power_cable B2_1.MP4 3_eI0eMcsl [107.338, 109.127]
# remove_pc_casing B2_1.MP4 3_WfpHKXaV [123.182, 127.459]
# connect_alligator_clip B2_1.MP4 3_URa4qwOi [133.065, 135.961]
# wear_wrist_wrap B2_1.MP4 3_QZr6fyu6 [137.669, 139.786]
# disconnect_display_cable B2_1.MP4 3_L1eh6HZV [111.835, 113.191]
# remove_hdd C1_1.MP4 1_UqAzness [202.968, 204.628]
# remove_odd C1_1.MP4 1_b5pDht7X [170.628, 172.688]
# remove_ram C1_1.MP4 1_hpTBrPw5 [121.065, 122.967]
# remove_ram C1_1.MP4 1_lgqmcz0v [126.481, 128.481]
# remove_vga C1_1.MP4 1_YN3mkeLG [109.883, 113.62]
# disconnect_atx_cable C1_1.MP4 1_F2DAJlkU [7.042, 11.104]
# disconnect_odd_power_cable C1_1.MP4 1_z1PdqDuQ [23.544, 25.443]
# disconnect_odd_data_cable C1_1.MP4 1_50w7PRUR [33.111, 36.254]
# disconnect_hdd_data_cable C1_1.MP4 1_SwRoUuQz [38.206, 40.139]
# disconnect_hdd_power_cable C1_1.MP4 1_6jc8Vv5M [27.798, 29.259]
# disconnect_hdd_data_cable C1_1.MP4 1_eXa4dbcf [47.432, 49.682]
# disconnect_odd_data_cable C1_1.MP4 1_YQlFJKeH [56.575, 59.075]
# disconnect_atx_cable C1_2.MP4 1_kyfdptPO [17.194, 19.211]
# disconnect_odd_power_cable C1_2.MP4 1_H3wkqgBG [30.252, 32.565]
# disconnect_hdd_power_cable C1_2.MP4 1_aFujKIhS [33.958, 35.318]
# disconnect_odd_data_cable C1_2.MP4 1_4biyTCVN [41.856, 43.548]
# disconnect_hdd_data_cable C1_2.MP4 1_JOqdkfMj [56.253, 60.755]
# remove_vga C1_2.MP4 1_5CqXB66I [78.333, 80.678]
# remove_ram C1_2.MP4 1_K3rHdQBY [95.356, 97.044]
# remove_ram C1_2.MP4 1_LKXedfkj [88.294, 90.398]
# remove_odd C1_2.MP4 1_beUmX3MX [125.481, 128.576]
# remove_hdd C1_2.MP4 1_QXVXpIXf [158.211, 160.073]
# disconnect_odd_data_cable C1_2.MP4 1_ayXg7TNz [49.255, 51.555]
# disconnect_atx_cable C1_3.MP4 1_i3tMlucH [16.523, 18.258]
# remove_vga C1_3.MP4 1_z2OVf04q [36.481, 39.959]
# remove_ram C1_3.MP4 1_xAm8oet6 [48.627, 51.759]
# remove_ram C1_3.MP4 1_m3gqs9Kd [56.19, 57.764]
# disconnect_odd_power_cable C1_3.MP4 1_YjT64D0D [69.731, 73.127]
# disconnect_odd_data_cable C1_3.MP4 1_BNHrXpqs [79.04, 84.759]
# disconnect_hdd_power_cable C1_3.MP4 1_tp6R6Vm9 [91.968, 93.618]
# disconnect_hdd_data_cable C1_3.MP4 1_vqvNXYbk [94.552, 97.759]
# remove_odd C1_3.MP4 1_Bkyej0ZK [127.419, 131.165]
# remove_hdd C1_3.MP4 1_xZSZcVkX [156.43, 158.666]
# insert_hdd E1_1.MP4 1_8l9xrhQG [9.252, 11.027]
# insert_odd E1_1.MP4 1_wZ4LTDJw [82.266, 88.106]
# insert_vga E1_1.MP4 1_cXB02LH2 [126.717, 137.289]
# remove_vga E1_1.MP4 1_rMQmgApT [187.15, 190.51]
# insert_ram E1_1.MP4 1_ZQcX8nyF [193.308, 201.208]
# insert_ram E1_1.MP4 1_MXbReRRp [202.713, 207.907]
# insert_vga E1_1.MP4 1_wYnIwkBv [217.057, 223.557]
# connect_hdd_data_cable E1_1.MP4 1_KlN383mV [228.105, 234.505]
# connect_odd_data_cable E1_1.MP4 1_sclc23sz [247.017, 265.777]
# connect_hdd_data_cable E1_1.MP4 1_BOZJznbA [269.547, 277.467]
# connect_hdd_power_cable E1_1.MP4 1_WXN6ATjZ [283.864, 288.147]
# connect_odd_power_cable E1_1.MP4 1_fKYLnuZC [290.474, 304.514]
# connect_atx_cable E1_1.MP4 1_VcjdOiDW [306.462, 311.862]
# put_back_pc_casing E1_1.MP4 1_D3E3MrJ2 [348.207, 353.505]
# insert_ram E1_2.MP4 1_a5M4pmM9 [5.867, 11.085]
# insert_ram E1_2.MP4 1_CAgmosqN [16.332, 22.04]
# insert_vga E1_2.MP4 1_5CPkEh8L [27.324, 37.432]
# insert_odd E1_2.MP4 1_AhmK3osu [42.497, 49.932]
# insert_hdd E1_2.MP4 1_7Uam8LSQ [94.277, 96.532]
# connect_hdd_data_cable E1_2.MP4 1_XdWgeZXV [140.639, 149.794]
# connect_hdd_power_cable E1_2.MP4 1_h296B5ip [151.628, 153.401]
# connect_odd_data_cable E1_2.MP4 1_y4e4rc1Q [168.259, 178.548]
# connect_odd_power_cable E1_2.MP4 1_DrbJoftL [179.302, 189.926]
# connect_atx_cable E1_2.MP4 1_rVYVXt3o [200.926, 206.181]
# put_back_pc_casing E1_2.MP4 1_KE1g62Wp [239.94, 246.968]
# put_back_pc_casing E1_2.MP4 1_YedK3eXM [258.583, 266.04]
# remove_pc_casing E1_2.MP4 1_0sbrgpUY [257.527, 258.555]
# insert_ram E1_3.MP4 1_WBaJfF7J [5.793, 12.353]
# insert_ram E1_3.MP4 1_9CcCdxdn [17.825, 22.165]
# insert_vga E1_3.MP4 1_Q73wuX5W [27.568, 37.212]
# insert_odd E1_3.MP4 1_TxbAOrsv [47.147, 53.103]
# insert_hdd E1_3.MP4 1_Q0Sma8nL [88.185, 93.284]
# connect_hdd_data_cable E1_3.MP4 1_ep3sE4GZ [149.014, 155.006]
# connect_hdd_power_cable E1_3.MP4 1_gg0GwNKx [164.691, 168.316]
# connect_odd_data_cable E1_3.MP4 1_jhvL9QWB [173.213, 184.505]
# connect_odd_power_cable E1_3.MP4 1_Mi0wyNg2 [187.092, 194.002]
# connect_atx_cable E1_3.MP4 1_rZ0Hd1Yj [201.592, 206.303]
# put_back_pc_casing E1_3.MP4 1_HAEujZnx [243.939, 248.504]
# connect_display_cable F1_2_1 (till 1.03).MP4 3_cVuKp39v [45.002, 47.023]
# login_screen F1_1_2.MP4 4_iXNbe1t8 [66.031, 68.697]
# enter_bios_mode F1_1_2.MP4 4_qU1CylK0 [13.231, 16.711]
# connect_display_cable F1_1_1.MP4 5_LgY7JJPQ [23.455, 26.505]
# login_screen F1_1_1.MP4 5_A1txQ0Nm [103.017, 105.72]
# login_screen F1_3.MP4 1_xg7SbZEC [113.836, 116.856]
# connect_display_cable F1_3.MP4 1_5FQYrmCh [18.349, 21.617]
# turn_on_pc F1_3.MP4 1_W3uIm1qM [53.428, 56.126]
# enter_bios_setup_mode F1_3.MP4 1_PWbffNkO [64.959, 68.459]
# verify_boot_sequence F1_3.MP4 1_X0LyutaZ [81.876, 89.428]
# turn_on_pc F1_2_2.MP4 2_atwn6Fjv [4.44, 7.106]
# enter_bios_setup_mode F1_2_2.MP4 2_f3CXyQ5p [20.199, 29.211]
# verify_boot_sequence F1_2_2.MP4 2_aqlJCVrQ [39.273, 44.002]
# login_screen F1_2_2.MP4 2_inXkrHWh [126.586, 130.586]
# turn_on_pc F1_2_1 (till 1.03).MP4 3_txgQR2yk [63.669, 66.565]
# turn_on_pc F1_1_2.MP4 4_9aQG4XyG [1.065, 3.836]
# verify_boot_sequence F1_1_2.MP4 4_pM6EPJbW [32.606, 37.752]
# turn_on_pc F1_1_1.MP4 5_xWNsSlRf [65.225, 69.015]
# login_screen A_5.MP4 1_FaMwyR68 [6.514, 9.443]
# turn_on_pc A_5.MP4 1_tGSJKzau [44.002, 46.162]
# turn_on_pc A_4.MP4 2_C3Hye373 [3.065, 4.94]
# login_screen A_4.MP4 2_xm80kkS0 [37.074, 38.514]
# turn_on_pc A_9.MP4 3_ZgsIohXe [2.794, 4.375]
# login_screen A_9.MP4 3_K4kjW5b7 [37.394, 40.956]
# switch_off_power B2_2.MP4 4_bGEJqAyO [28.419, 29.681]
# switch_off_power_source B2_2.MP4 4_8JuTzE56 [36.675, 40.565]
# unplug_power_cable B2_2.MP4 4_wxr4BRXm [52.225, 55.336]
# place_anti_static_mat B2_2.MP4 4_xbpSkUiX [83.091, 85.781]
# connect_alligator_clip B2_2.MP4 4_f5LAlC6h [147.281, 149.277]
# wear_wrist_wrap B2_2.MP4 4_mNO6aK43 [159.744, 161.364]
# remove_pc_casing B2_2.MP4 4_kSle1LJg [196.527, 200.67]
# disconnect_display_cable B2_2.MP4 4_SfWpRNfe [59.856, 63.669]
# connect_alligator_clip B2_2.MP4 4_6eERZe6w [124.231, 126.023]
# connect_alligator_clip B2_2.MP4 4_Edo4Bie4 [137.002, 143.877]
# disconnect_hdd_data_cable C1_4.MP4 2_0seglKYm [76.027, 78.94]
# disconnect_hdd_power_cable C1_4.MP4 2_nPGrEATt [85.961, 89.023]
# remove_hdd C1_4.MP4 2_s2DIjiDe [92.961, 95.981]
# remove_odd C1_4.MP4 2_xNC2wHCb [227.023, 230.08]
# remove_vga C1_4.MP4 2_9ia8cUGt [329.919, 332.94]
# remove_ram C1_4.MP4 2_4CWVq4Le [343.081, 346.315]
# remove_ram C1_4.MP4 2_Q3qWeL19 [351.94, 354.859]
# disconnect_odd_data_cable C1_4.MP4 2_XLulSVXK [242.046, 244.63]
# disconnect_odd_data_cable C1_4.MP4 2_Ken66LkN [254.713, 256.463]
# disconnect_hdd_data_cable C1_4.MP4 2_97ERTBDW [265.509, 266.592]
# insert_hdd E1_5.MP4 1_BAxbXL3h [14.468, 18.468]
# insert_odd E1_5.MP4 1_TkrYR6fj [145.887, 156.277]
# insert_vga E1_5.MP4 1_5qOJLrG9 [258.927, 267.277]
# insert_vga E1_5.MP4 1_OWyIN85B [363.145, 372.027]
# insert_ram E1_5.MP4 1_70r9ZV5R [473.712, 480.627]
# connect_odd_data_cable E1_5.MP4 1_xRtiTDX3 [584.979, 592.861]
# connect_hdd_data_cable E1_5.MP4 1_BTVXXAzp [668.277, 700.277]
# put_back_pc_casing E1_5.MP4 1_4AjlBDEF [789.027, 798.027]
# insert_hdd E1_5.MP4 1_Mnacy9Yd [55.682, 60.811]
# remove_hdd E1_5.MP4 1_Pt5QHj65 [37.527, 39.682]
# insert_hdd E1_5.MP4 1_BjydT1fH [41.807, 48.257]
# remove_hdd E1_5.MP4 1_cVz2yeXj [48.257, 50.257]
# remove_vga E1_5.MP4 1_kE2tHvXX [354.777, 357.757]
# insert_ram E1_5.MP4 1_wc2xdqsw [496.218, 505.278]
# connect_hdd_power_cable E1_5.MP4 1_U0gBCfbG [616.425, 622.527]
# connect_odd_data_cable E1_5.MP4 1_UXTGXbsu [639.527, 643.527]
# wear_wrist_wrap E1_5.MP4 1_VfXyBULH [1.467, 4.467]
# put_back_pc_casing E1_5.MP4 1_IOCy4XE6 [802.479, 812.577]
# connect_odd_power_cable E1_5.MP4 1_LYBcuaoo [555.978, 563.342]
# turn_on_pc F1_4.MP4 1_ec8hXrIs [94.815, 97.711]
# connect_display_cable F1_4.MP4 1_VpPkK07h [16.069, 19.386]
# login_screen F1_4.MP4 1_QaZ8p1eN [221.641, 222.935]
# enter_bios_setup_mode F1_4.MP4 1_XpqSXOfo [108.631, 112.143]
# verify_boot_sequence F1_4.MP4 1_bliS69Cx [188.471, 193.523]
# turn_on_pc A_10.MP4 1_q1cxshZt [3.148, 5.086]
# login_screen A_10.MP4 1_c8uRODmP [37.148, 40.106]
# turn_on_pc A_11.MP4 2_gyqNiFfS [1.794, 4.669]
# login_screen A_11.MP4 2_4ePIfBXP [36.044, 38.925]
# turn_on_pc A_8.MP4 3_XR4vw8rf [4.269, 5.69]
# login_screen A_8.MP4 3_cSjSb8aH [37.972, 39.552]
# turn_on_pc A_7.MP4 4_tRsDXp6t [2.899, 4.626]
# login_screen A_7.MP4 4_WrCnwtCf [38.449, 40.152]
# turn_on_pc A_6.MP4 5_nAJBdVov [2.648, 3.868]
# login_screen A_6.MP4 5_61SGrzhn [44.19, 45.53]
# switch_off_power B3_1.MP4 5_MrXmBR2w [7.669, 8.669]
# switch_off_power_source B3_1.MP4 5_6Id5wxoD [12.149, 13.836]
# unplug_power_cable B3_1.MP4 5_Xsz90Nyb [17.038, 17.927]
# place_anti_static_mat B3_1.MP4 5_5pUMd5C0 [35.793, 38.315]
# wear_wrist_wrap B3_1.MP4 5_ulkXpKO4 [61.707, 63.287]
# connect_alligator_clip B3_1.MP4 5_exHfDQAl [68.772, 72.618]
# remove_pc_casing B3_1.MP4 5_u6quDCFL [89.592, 91.469]
# disconnect_display_cable B3_1.MP4 5_WJT3BBQS [21.502, 22.752]
# switch_off_power B4_1.MP4 7_sfAkU6Iq [17.002, 18.002]
# switch_off_power_source B4_1.MP4 7_MX6CIACd [23.794, 27.586]
# place_anti_static_mat B4_1.MP4 7_qj9DjcWg [35.842, 37.505]
# unplug_power_cable B4_1.MP4 7_Ty8XAftn [56.296, 57.336]
# wear_wrist_wrap B4_1.MP4 7_z9S6GioE [135.148, 136.389]
# connect_alligator_clip B4_1.MP4 7_grTaq9qX [140.985, 146.023]
# remove_pc_casing B4_1.MP4 7_XKardBNH [149.711, 153.544]
# disconnect_display_cable B4_1.MP4 7_dLVrP1sX [61.932, 62.993]

# %%
#count how many annotations
c=0
for filename, annotations in ann_dict.items():
    c+=len(annotations)
print(c)
# Out:
# 235

# %%
#sort annotations by time
for filename, annotations in ann_dict.items():
#     print(f'before sorting:')
#     for i in annotations[:10]:
#         print(i)
    
    annotations = sorted(annotations, key=lambda i: i['z'][0])
    ann_dict[filename]=annotations
#     print(f'after sorting:')
#     for i in ann_dict[filename][:10]:
#         print(i)

# %% [markdown]
# ### Extract clips from videos
# - P.S CSV FILE CONTAINING THE ACTION TIMESTAMP IS SAVED HERE FOR ALL THE FULL VIDEOS

# %%
#extract clips from videos
random.seed(112)
buffer = 0.5 # buffer between no_action and action

translator = {'disconnect_atx_cableT': 'disconnect_atx_cable',
              '_DEFdisconnect_atx_cableAULT':'disconnect_atx_cable',
             'connect_odd_cable': 'connect_odd_data_cable', 
             'connect_odd_data_ cable': 'connect_odd_data_cable', 
             'insert_hdd_data_cable':'connect_hdd_data_cable',
             'insert_odd_data_cable': 'connect_odd_data_cable',
             'enter_bios_mode':'enter_bios_setup_mode'}

for filename, annotations in ann_dict.items():
    print(filename)
    video_path = vid_path_dict[filename]#os.path.join(VIDEOS_DIR, filename)
    prev_end = 0
    with open(video_path+'.csv', 'w') as csv_file:
        csv_file.write(f'action,z_start,z_end\n')
        for annotation in annotations:
            action = annotation['action_name']
            if action in translator.keys():
                action = translator[action]
            z_start, z_end = annotation['z'] #z is in seconds
            
            # extend annotation ###########################################################
#             extend_list = ['insert_ram', 'insert_vga', 'place_anti_static_mat', 'put_back_pc_casing']
#             if action in extend_list:
#                 z_start = z_start-2
#                 z_start = max(z_start, 0)
            ################################################################################
                
            annotation_id = annotation['annotation_id']
            target_dir = os.path.join(CLIPS_DIR, action)
            Path(target_dir).mkdir(exist_ok=True)

            target_filepath = os.path.join(target_dir, f'{annotation_id}_{filename}')


            ffmpeg_extract_subclip(video_path, z_start, z_end, targetname=target_filepath)
            csv_file.write(f'{action},{z_start},{z_end}\n')
            
            #extract no action clip
            action = 'no_action'
            annotation_id = annotation['annotation_id']
            target_dir = os.path.join(CLIPS_DIR, action)
            Path(target_dir).mkdir(exist_ok=True)

            duration = random.uniform(3, 10)
            #add buffer to z_start and prev_end
            z_start -= buffer
            prev_end += buffer
            #skip if gap is too small / overlap
            if z_start - prev_end < 0.3:
                continue
            
            if z_start - prev_end < duration: # if gap between action is too short, take whole gap as no action
                na_start = prev_end
                na_end = z_start
            else:
                na_start = random.uniform(prev_end, z_start-duration)
                na_end = na_start + duration

            target_filepath = os.path.join(target_dir, f'{annotation_id}_no_action_{filename}')
    #         print('action: ', z_start, z_end)
    #         print('no action:', na_start, na_end)
    #         print(target_filepath)
            ffmpeg_extract_subclip(video_path, na_start, na_end, targetname=target_filepath)
            csv_file.write(f'{action},{na_start},{na_end}\n')
            prev_end = z_end
# Out:
# VID00002.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_3.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# B1_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# B1_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# B2_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# C1_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# C1_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# C1_3.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# E1_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# E1_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# E1_3.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# F1_2_1 (till 1.03).MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# F1_1_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# F1_1_1.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# F1_3.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# F1_2_2.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_5.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_4.MP4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# A_9.MP4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-b94eac97300b> in <module>
#      13 for filename, annotations in ann_dict.items():
#      14     print(filename)
# ---> 15     video_path = vid_path_dict[filename]#os.path.join(VIDEOS_DIR, filename)
#      16     prev_end = 0
#      17     with open(video_path+'.csv', 'w') as csv_file:
#
# KeyError: 'A_9.MP4'
